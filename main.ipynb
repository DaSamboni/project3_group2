# %%
import pandas as pd

# %%
vehicle_df = pd.read_csv("resources/veh_19.csv", low_memory = False)
people_df = pd.read_csv("resources/pers_19.csv", low_memory = False)
accident_df = pd.read_csv("resources/acc_19.csv", low_memory = False)

# %%
vehicle_df.head()
# Out:
#         CASENUM  VEH_NO  STRATUM                       STRATUMNAME  REGION  \
# 0  201901174219       1       10                Stratum 10 - Other       3
# 1  201901176655       1        6   Stratum 6 - LMY PV Minor Injury       3
# 2  201901176655       2        6   Stratum 6 - LMY PV Minor Injury       3
# 3  201901176667       1        8  Stratum 8 - NLMY PV Minor Injury       3
# 4  201901176667       2        8  Stratum 8 - NLMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
#
#    URBANICITY  ... VEVENT_IM               VEVENT_IMNAME  PCRASH1_IM  \
# ...

# %%
people_df.head()
# Out:
#         CASENUM  VE_FORMS  VEH_NO  PER_NO  STRATUM  \
# 0  201901174219         1       1       1       10
# 1  201901176655         2       1       1        6
# 2  201901176655         2       1       2        6
# 3  201901176655         2       1       3        6
# 4  201901176655         2       1       4        6
#
#                        STRATUMNAME  REGION  \
# 0               Stratum 10 - Other       3
# 1  Stratum 6 - LMY PV Minor Injury       3
# 2  Stratum 6 - LMY PV Minor Injury       3
# 3  Stratum 6 - LMY PV Minor Injury       3
# 4  Stratum 6 - LMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  ...  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144  ...
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# ...

# %%
accident_df.head()
# Out:
#         CASENUM  STRATUM                              STRATUMNAME  REGION  \
# 0  201901174219       10                       Stratum 10 - Other       3
# 1  201901176655        6          Stratum 6 - LMY PV Minor Injury       3
# 2  201901176667        8         Stratum 8 - NLMY PV Minor Injury       3
# 3  201901176694        9  Stratum 9 - LMY PV No Injuries in Crash       3
# 4  201901176702        6          Stratum 6 - LMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
#
#    URBANICITY URBANICITYNAME  ...  LGTCON_IM   LGTCON_IMNAME  WEATHR_IM  \
# ...

# %%
# Displays all the column
pd.set_option('display.max_columns', None)
people_df.head(2)
# Out:
#         CASENUM  VE_FORMS  VEH_NO  PER_NO  STRATUM  \
# 0  201901174219         1       1       1       10
# 1  201901176655         2       1       1        6
#
#                        STRATUMNAME  REGION  \
# 0               Stratum 10 - Other       3
# 1  Stratum 6 - LMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
#
#    URBANICITY URBANICITYNAME  STR_VEH  MONTH MONTHNAME  HOUR       HOURNAME  \
# 0           2     Rural Area        0      1   January     8  8:00am-8:59am
# 1           2     Rural Area        0      1   January     2  2:00am-2:59am
#
#    MINUTE MINUTENAME  HARM_EV                 HARM_EVNAME  MAN_COLL  \
# 0       6          6       33                        Curb         0
# 1      12         12       12  Motor Vehicle In-Transport         6
#
# ...

# %%
new_people_df = people_df[["CASENUM","STRATUM","REGION","REGIONNAME","PSU","PJ","URBANICITYNAME","MONTHNAME","HOURNAME","MINUTE","HARM_EVNAME","MAN_COLLNAME",
                               "MAKENAME","MAK_MODNAME","MOD_YEARNAME","TOW_VEHNAME","ROLLOVERNAME","IMPACT1NAME","AGENAME","SEXNAME","PER_TYPNAME","INJ_SEVNAME",
                               "SEAT_POSNAME","AIR_BAGNAME","DRINKINGNAME","ALC_STATUSNAME","DRUGSNAME","HOSPITALNAME"]]
new_people_df.head()
# Out:
#         CASENUM  STRATUM  REGION  \
# 0  201901174219       10       3
# 1  201901176655        6       3
# 2  201901176655        6       3
# 3  201901176655        6       3
# 4  201901176655        6       3
#
#                                           REGIONNAME  PSU    PJ  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135
#
#   URBANICITYNAME MONTHNAME       HOURNAME  MINUTE                 HARM_EVNAME  \
# 0     Rural Area   January  8:00am-8:59am       6                        Curb
# 1     Rural Area   January  2:00am-2:59am      12  Motor Vehicle In-Transport
# 2     Rural Area   January  2:00am-2:59am      12  Motor Vehicle In-Transport
# ...
